# %% [markdown]
# - The dataset is a great collection of images, since the labels are in the following format: 'Hardhat', 'Mask', 'NO-Hardhat', 'NO-Mask', 'NO-Safety Vest', 'Person', 'Safety Cone', 'Safety Vest', 'machinery', 'vehicle'
#
# - **Quick Summary**
#     - Number of classes: 10
#     - Label Annotation: YOLO format (.txt)
#     - Metadata: metadata.csv and count.csv provides information about the dataset and train-val-test count information.
#     - PPE Class Map: {0: 'Hardhat', 1: 'Mask', 2: 'NO-Hardhat', 3: 'NO-Mask', 4: 'NO-Safety Vest', 5: 'Person', 6: 'Safety Cone', 7: 'Safety Vest', 8: 'machinery', 9: 'vehicle'}
#     - Difficulty: This is a beginner-friendly dataset on multi-class classification, object detection, and tracking. Annotations are in YoloV8 format. The splits are given in the dataset folder itself with metadata, so anyone can use this data to run models and produce results.

# %%
import numpy as np
import pandas as pd
import warnings
import matplotlib.pyplot as plt
from IPython.core.magic import register_line_cell_magic
import yaml
from PIL import Image
import os
import seaborn as sns
from ultralytics import YOLO
from matplotlib.patches import Rectangle
import glob
import cv2

# %%
INPUT_DIR = 'css-data'
WORK_DIR = ''

# %%
num_classes = 10
classes = ['Hardhat', 'Mask', 'NO-Hardhat', 'NO-Mask', 'NO-Safety Vest', 'Person', 'Safety Cone', 'Safety Vest', 'machinery', 'vehicle']

# %%
dict_file = {'train': os.path.join(INPUT_DIR, 'train'),
             'val': os.path.join(INPUT_DIR, 'valid'),
             'test': os.path.join(INPUT_DIR, 'test'),
             'nc': num_classes,
             'names': classes
            }

with open(os.path.join(WORK_DIR, 'data.yaml'), 'w+') as file:
    yaml.dump(dict_file, file)

# %%
class_idx = {str(i):classes[i] for i in range(num_classes)}

class_stat = {}
data_len = {}

for mode in ['train', 'valid', 'test']:

    class_count = {classes[i]:0 for i in range(num_classes)}

    path = os.path.join(INPUT_DIR, mode, 'labels')

    for file in os.listdir(path):

        with open(os.path.join(path, file)) as f:
            lines = f.readlines()

            for cls in set([line[0] for line in lines]):
                class_count[class_idx[cls]] += 1
                
    data_len[mode] = len(os.listdir(path))
    class_stat[mode] = class_count

# %%
fig, ax = plt.subplots(1,3, figsize=(15, 5), sharey=True)

for i, mode in enumerate(['train', 'valid', 'test']):
    sns.barplot(pd.DataFrame({mode:class_stat[mode]}).T/data_len[mode]*100, ax=ax[i])
    ax[i].set_title(mode)
    ax[i].tick_params(rotation=90)
    ax[i].set_ylabel('Percenatage of classes')
plt.show()

# %%
for mode in ['train', 'valid', 'test']:
    print(f'\nImage sizes in {mode} set:\n')
    img_size = 0
    for file in glob.glob(os.path.join(INPUT_DIR, mode, 'images', '*')):
        image = Image.open(file)
        if image.size != img_size:
            print(f'\t{image.size}')
            img_size = image.size
# Out:
# Image sizes in train set:
#
# 	(640, 640)
#
# Image sizes in valid set:
#
# 	(640, 640)
#
# Image sizes in test set:
#
# 	(640, 640)

# %%
for mode in ['train', 'valid', 'test']:
    
    files =  glob.glob(os.path.join(INPUT_DIR, mode, 'images', '*'))
        
    print(f'{mode} set size: {len(files)}\n')
# Out:
# train set size: 2605
#
# valid set size: 114
#
# test set size: 82

# %% [markdown]
# - Load `pre-trained` YOLO-nano model

# %%
model = YOLO('yolov8n.pt')
# Out:
# Downloading https://github.com/ultralytics/assets/releases/download/v0.0.0/yolov8n.pt to yolov8n.pt...
#   0%|          | 0.00/6.23M [00:00<?, ?B/s
00:00,  1.35it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 2/2 [00:02<00:00,  1.00s/it]
#                    all        114        697      0.802      0.621      0.692       0.39
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       22/30       7.9G      1.029     0.9756      1.222        109        640: 100%|██████████| 82/82 [00:58<00:00,  1.41it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 2/2 [00:02<00:00,  1.06s/it]
#                    all        114        697      0.837      0.618      0.695      0.363
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       23/30       7.9G      1.011     0.9491      1.208        218        640: 100%|██████████| 82/82 [00:59<00:00,  1.39it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 2/2 [00:02<00:00,  1.09s/it]
#                    all        114        697       0.82       0.62      0.702      0.397
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       24/30       7.9G     0.9978     0.9251      1.198        190        640: 100%|██████████| 82/82 [00:58<00:00,  1.41it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 2/2 [00:02<00:00,  1.03s/it]
#                    all        114        697      0.786      0.658      0.708      0.383
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       25/30       7.9G      0.979     0.9073       1.19        146        640: 100%|██████████| 82/82 [00:57<00:00,  1.43it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 2/2 [00:02<00:00,  1.09s/it]
#                    all        114        697      0.844      0.665      0.727        0.4
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       26/30       7.9G     0.9661     0.8849      1.185        139        640: 100%|██████████| 82/82 [00:57<00:00,  1.43it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 2/2 [00:02<00:00,  1.01s/it]
#                    all        114        697      0.829      0.684      0.744      0.403
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       27/30       7.9G     0.9515     0.8683      1.171        152        640: 100%|██████████| 82/82 [00:57<00:00,  1.42it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 2/2 [00:02<00:00,  1.08s/it]
#                    all        114        697      0.872      0.656      0.735      0.396
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       28/30       7.9G     0.9415     0.8436      1.165        175        640: 100%|██████████| 82/82 [00:58<00:00,  1.39it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 2/2 [00:02<00:00,  1.01s/it]
#                    all        114        697      0.862      0.654      0.733      0.417
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       29/30       7.9G     0.9273     0.8256      1.156        138        640: 100%|██████████| 82/82 [01:01<00:00,  1.34it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 2/2 [00:02<00:00,  1.18s/it]
#                    all        114        697      0.882      0.664      0.751      0.429
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       30/30       7.9G     0.9117     0.8078      1.147        165        640: 100%|██████████| 82/82 [00:58<00:00,  1.41it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 2/2 [00:03<00:00,  1.63s/it]
#                    all        114        697      0.909      0.664       0.75      0.432
#
# 30 epochs completed in 0.743 hours.
# Optimizer stripped from runs/detect/yolov8n_v1_train/weights/last.pt, 6.2MB
# Optimizer stripped from runs/detect/yolov8n_v1_train/weights/best.pt, 6.2MB
#
# Validating runs/detect/yolov8n_v1_train/weights/best.pt...
# Ultralytics YOLOv8.0.55 🚀 Python-3.7.12 torch-1.13.0 CUDA:0 (Tesla P100-PCIE-16GB, 16281MiB)
# Model summary (fused): 168 layers, 3007598 parameters, 0 gradients, 8.1 GFLOPs
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 2/2 [00:03<00:00,  1.63s/it]
#                    all        114        697      0.907      0.666      0.751      0.434
#                Hardhat        114         79      0.932      0.734      0.817      0.513
#                   Mask        114         21      0.971       0.81      0.851      0.549
#             NO-Hardhat        114         69      0.881      0.536      0.637      0.291
#                NO-Mask        114         74      0.865      0.473      0.574      0.276
#         NO-Safety Vest        114        106      0.887      0.594      0.742      0.403
#                 Person        114        166      0.875      0.678      0.788      0.464
#            Safety Cone        114         44       0.97      0.841      0.886      0.476
#            Safety Vest        114         41      0.963      0.756      0.824      0.482
#              machinery        114         55       0.91      0.855      0.922      0.601
#                vehicle        114         42       0.82      0.381      0.473      0.282
# Speed: 1.9ms preprocess, 3.1ms inference, 0.0ms loss, 1.9ms postprocess per image
# Results saved to runs/detect/yolov8n_v1_train

# %%
model = YOLO('runs/detect/yolov8n_v1_train/weights/best.pt')

# %%
results = model.predict(source=os.path.join(INPUT_DIR, 'test', 'images'), save=True)
# Out:
# image 1/82 /kaggle/input/construction-site-safety-image-dataset-roboflow/css-data/test/images/-4405-_png_jpg.rf.82b5c10b2acd1cfaa24259ada8e599fe.jpg: 640x640 1 Hardhat, 1 NO-Safety Vest, 1 Person, 1 machinery, 14.9ms
# image 2/82 /kaggle/input/construction-site-safety-image-dataset-roboflow/css-data/test/images/000005_jpg.rf.96e9379ccae638140c4a90fc4b700a2b.jpg: 640x640 2 Hardhats, 2 NO-Masks, 1 NO-Safety Vest, 2 Persons, 11.7ms
# image 3/82 /kaggle/input/construction-site-safety-image-dataset-roboflow/css-data/test/images/002551_jpg.rf.ce4b9f934161faa72c80dc6898d37b2d.jpg: 640x640 2 Hardhats, 1 NO-Mask, 2 NO-Safety Vests, 4 Persons, 11.9ms
# image 4/82 /kaggle/input/construction-site-safety-image-dataset-roboflow/css-data/test/images
82 /kaggle/input/construction-site-safety-image-dataset-roboflow/css-data/test/images/IMG_5846_jpg.rf.0b9984069116e2acd928568eb7a8e214.jpg: 640x640 21 Hardhats, 29 NO-Masks, 24 Persons, 25 Safety Vests, 11.7ms
# image 24/82 /kaggle/input/construction-site-safety-image-dataset-roboflow/css-data/test/images/Image36_jpg.rf.8704f3450f736cdd01a61dcee588f2c2.jpg: 640x640 10 Hardhats, 4 NO-Masks, 11 NO-Safety Vests, 16 Persons, 11.3ms
# image 25/82 /kaggle/input/construction-site-safety-image-dataset-roboflow/css-data/test/images/Inside-merge_mov-58_jpg.rf.50147e19cb655e74c2df0047113e82b2.jpg: 640x640 (no detections), 11.2ms
# image 26/82 /kaggle/input/construction-site-safety-image-dataset-roboflow/css-data/test/images/Movie-on-10-31-22-at-10_08-AM_mov-20_jpg.rf.aea4278b41550cdb75df5891a26052e7.jpg: 640x640 1 Mask, 1 NO-Hardhat, 1 NO-Safety Vest, 1 Person, 11.3ms
# image 27/82 /kaggle/input/construction-site-safety-image-dataset-roboflow/css-data/test/images/Movie-on-10-31-22-at-10_08-AM_mov-24_jpg.rf.c50014f3510a484e5bd565460fd0fd5c.jpg: 640x640 1 Mask, 2 NO-Hardhats, 1 NO-Safety Vest, 1 Person, 11.7ms
# image 28/82 /kaggle/input/construction-site-safety-image-dataset-roboflow/css-data/test/images/NX_img_177_jpg.rf.c03709e5fadfe2109411f05a9e9bc25f.jpg: 640x640 1 Hardhat, 1 NO-Hardhat, 3 NO-Safety Vests, 3 Persons, 11.4ms
# image 29/82 /kaggle/input/construction-site-safety-image-dataset-roboflow/css-data/test/images/RPReplay_Final1667001201_MP4-100_jpg.rf.9a1b50c4301c53b3ae534c6353337df9.jpg: 640x640 1 Mask, 1 NO-Hardhat, 1 NO-Safety Vest, 1 Person, 11.4ms
# image 30/82 /kaggle/input/construction-site-safety-image-dataset-roboflow/css-data/test/images/autox3_mp4-187_jpg.rf.8340e2bd65afade3fb0d3194eadc5796.jpg: 640x640 5 Safety Cones, 1 vehicle, 11.4ms
# image 31/82 /kaggle/input/construction-site-safety-image-dataset-roboflow/css-data/test/images/autox3_mp4-277_jpg.rf.a5ed8fd043fe7e1d8682768880b6d4db.jpg: 640x640 25 Safety Cones, 1 vehicle, 11.7ms
# image 32/82 /kaggle/input/construction-site-safety-image-dataset-roboflow/css-data/test/images/autox3_mp4-65_jpg.rf.d933ce48947fa9bdb55dc702a0879ac9.jpg: 640x640 3 Safety Cones, 1 vehicle, 11.4ms
# image 33/82 /kaggle/input/construction-site-safety-image-dataset-roboflow/css-data/test/images/autox_mp4-44_jpg.rf.5048603ee6ccedf9ae6e3f787b7f82ff.jpg: 640x640 19 Safety Cones, 1 vehicle, 11.2ms
# image 34/82 /kaggle/input/construction-site-safety-image-dataset-roboflow/css-data/test/images/bookstore_44_08_flickr_jpg.rf.244b6f308c529933af798c4063e58601.jpg: 640x640 (no detections), 11.2ms
# image 35/82 /kaggle/input/construction-site-safety-image-dataset-roboflow/css-data/test/images/class1_150_jpg.rf.5995dce34d38deb9eb0b6e36cae78f17.jpg: 640x640 1 Hardhat, 1 NO-Hardhat, 2 NO-Safety Vests, 2 Persons, 11.5ms
# image 36/82 /kaggle/input/construction-site-safety-image-dataset-roboflow/css-data/test/images/class2_131_jpg.rf.ad8314a9273471f1280ce8789ea75376.jpg: 640x640 2 NO-Safety Vests, 1 Person, 11.2ms
# image 37/82 /kaggle/input/construction-site-safety-image-dataset-roboflow/css-data/test/images/class2_145_jpg.rf.b8ed5a5357ee41f8fb1aa9b01a400d51.jpg: 640x640 2 NO-Hardhats, 2 NO-Safety Vests, 2 Persons, 11.0ms
# image 38/82 /kaggle/input/construction-site-safety-image-dataset-roboflow/css-data/test/images/construction-1159-_jpg.rf.9f3172102a34edb157b556a73931c831.jpg: 640x640 1 machinery, 11.6ms
# image 39/82 /kaggle/input/construction-site-safety-image-dataset-roboflow/css-data/test/images/construction-192-_jpg.rf.56dd5c4c1396c6ad01be4fbec3bca46f.jpg: 640x640 1 Person, 3 machinerys, 11.5ms
# image 40/82 /kaggle/input/construction-site-safety-image-dataset-roboflow/css-data/test/images/construction-2-_mp4-13_jpg.rf.cef0975976346515d438e0c2ce6c59db.jpg: 640x640 4 machinerys, 12.0ms
# image 41/82 /kaggle/input/construction-site-safety-image-dataset-roboflow/css-data/test/images/construction-2-_mp4-162_jpg.rf.efad5f15524c736fe03b9c9936adc481.jpg: 640x640 3 machinerys, 11.7ms
# image 42/82 /kaggle/input/construction-site-safety-image-dataset-roboflow/css-data/test/images/construction-2-_mp4-84_jpg.rf.e8d6bb0acc5c6e82c1a2d260ddf3135e.jpg: 640x640 2 machinerys, 11.6ms
# image 43/82 /kaggle/input/construction-site-safety-image-dataset-roboflow/css-data/test/images/construction-275-_jpg.rf.e1c57987f9dc262aad1d7c67b694fd87.jpg: 640x640 1 machinery, 12.1ms
# image 44/82 /kaggle/input/construction-site-safety-image-dataset-roboflow/css-data/test/images/construction-597-_jpg.rf.e18e918aae0aeecfdf8348513636d344.jpg: 640x640 2 machinerys, 12.0ms
# image 45/82 /kaggle/input/construction-site-safety-image-dataset-roboflow/css-data/test/images/construction-639-_jpg.rf.7db2168ad99f643f7e3070733387e3bb.jpg: 640x640 1 machinery, 11.6ms
# image 46/82 /kaggle/input/construction-site-safety-image-dataset-roboflow/css-data/test/images/construction-651-_jpg.rf.8fa283ce7693dbdf29eb98384f24cb85.jpg: 640x640 1 machinery, 11.4ms
# image 47/82 /kaggle/input/construction-site-safety-image-dataset-roboflow/css-data/test/images/construction-675-_jpg.rf.bb4a05441be707256175e04929da3478.jpg: 640x640 1 machinery, 11.4ms
# image 48/82 /kaggle/input/construction-site-safety-image-dataset-roboflow/css-data/test/images/construction-800-_jpg.rf.a01fcddd0db9cc89c0cacf4af88c468d.jpg: 640x640 2 machinerys, 11.8ms
# image 49/82 /kaggle/input/construction-site-safety-image-dataset-roboflow/css-data/test/images/construction-843-_jpg.rf.c0ca85a10f6ad3c1375b37e52a51eeed.jpg: 640x640 4 machinerys, 11.4ms
# image 50/82 /kaggle/input/construction-site-safety-image-dataset-roboflow/css-data/test/images/image_53_jpg.rf.3446e366b5d4d905a32e1aedc8fe87de.jpg: 640x640 1 Hardhat, 1 Mask, 2 Persons, 1 Safety Vest, 11.9ms
# image 51/82 /kaggle/input/construction-site-safety-image-dataset-roboflow/css-data/test/images/image_55_jpg.rf.27ae4341a9b9647d73a8929ff7a22369.jpg: 640x640 1 Hardhat, 1 Mask, 1 Person, 1 Safety Vest, 11.5ms
# image 52/82 /kaggle/input/construction-site-safety-image-dataset-roboflow/css-data/test/images/ka_01181_png_jpg.rf.154ee4ef254eabd62e316be50470c578.jpg: 640x640 5 Safety Cones, 1 vehicle, 11.2ms
# image 53/82 /kaggle/input/construction-site-safety-image-dataset-roboflow/css-data/test/images/librairie_51_jpg.rf.56b0500ae2ad3820b4286133b627e59c.jpg: 640x640 1 Person, 12.0ms
# image 54/82 /kaggle/input/construction-site-safety-image-dataset-roboflow/css-data/test/images/maksssksksss17_png_jpg.rf.f685b497756b1facbf3d4c2d2d22c0d2.jpg: 640x640 1 Mask, 1 NO-Hardhat, 2 NO-Safety Vests, 1 Person, 11.5ms
# image 55/82 /kaggle/input/construction-site-safety-image-dataset-roboflow/css-data/test/images/ppe_0018_jpg.rf.be66fabcc8627f60d963454b5a227095.jpg: 640x640 2 Hardhats, 2 NO-Masks, 2 NO-Safety Vests, 2 Persons, 11.0ms
# image 56/82 /kaggle/input/construction-site-safety-image-dataset-roboflow/css-data/test/images/ppe_1073_jpg.rf.72ea8a293a4f3e1135219e33701b1099.jpg: 640x640 10 Hardhats, 4 NO-Masks, 12 Persons, 9 Safety Vests, 10.7ms
# image 57/82 /kaggle/input/construction-site-safety-image-dataset-roboflow/css-data/test/images/thumbnail-ba5c72edb320b49a69e86b05775c49b2-scaled-1_jpeg_jpg.rf.3bb460e284098219861b894fb0db13d5.jpg: 640x640 8 Masks, 8 NO-Hardhats, 14 NO-Safety Vests, 9 Persons, 11.2ms
# image 58/82 /kaggle/input/construction-site-safety-image-dataset-roboflow/css-data/test/images/youtube-108_jpg.rf.9dc7ed5f816f07d520f3dbfaad08d40f.jpg: 640x640 2 Hardhats, 2 NO-Masks, 2 Persons, 2 Safety Vests, 11.9ms
# image 59/82 /kaggle/input/construction-site-safety-image-dataset-roboflow/css-data/test/images/youtube-114_jpg.rf.5e02b6574ace1f4b3689befbc5051cd0.jpg: 640x640 1 NO-Mask, 2 NO-Safety Vests, 2 Persons, 11.3ms
# image 60/82 /kaggle/input/construction-site-safety-image-dataset-roboflow/css-data/test/images/youtube-126_jpg.rf.786824e90daf3276130ca73ca610a8da.jpg: 640x640 2 NO-Hardhats, 1 NO-Mask, 2 NO-Safety Vests, 2 Persons, 4 machinerys, 11.5ms
# image 61/82 /kaggle/input/construction-site-safety-image-dataset-roboflow/css-data/test/images/youtube-152_jpg.rf.9147878e3ddda845e58f7d9c041f1338.jpg: 640x640 5 Persons, 5 machinerys, 1 vehicle, 11.7ms
# image 62/82 /kaggle/input/construction-site-safety-image-dataset-roboflow/css-data/test/images/youtube-186_jpg.rf.1f1d93447d4be3233c22c4ce9f6e0601.jpg: 640x640 1 Hardhat, 1 Person, 1 Safety Vest, 11.4ms
# image 63/82 /kaggle/input/construction-site-safety-image-dataset-roboflow/css-data/test/images/youtube-192_jpg.rf.93bea040de8cd55f34ffb12f6ffe30b1.jpg: 640x640 1 Mask, 1 NO-Hardhat, 1 NO-Mask, 1 NO-Safety Vest, 1 Person, 11.8ms
# image 64/82 /kaggle/input/construction-site-safety-image-dataset-roboflow/css-data/test/images/youtube-198_jpg.rf.e89faeb9765c6bd6cece5434d140f4af.jpg: 640x640 2 Persons, 1 Safety Vest, 3 machinerys, 11.5ms
# image 65/82 /kaggle/input/construction-site-safety-image-dataset-roboflow/css-data/test/images/youtube-213_jpg.rf.da70b1d8cefd3cc9d56e43bb88dfb67d.jpg: 640x640 1 Hardhat, 1 Person, 1 Safety Vest, 1 machinery, 11.3ms
# image 66/82 /kaggle/input/construction-site-safety-image-dataset-roboflow/css-data/test/images/youtube-237_jpg.rf.d07a927721fe259757237c3706ea22e5.jpg: 640x640 3 Hardhats, 2 NO-Safety Vests, 2 Persons, 2 machinerys, 6 vehicles, 11.0ms
# image 67/82 /kaggle/input/construction-site-safety-image-dataset-roboflow/css-data/test/images/youtube-253_jpg.rf.5ad0a2d701e20141940508b809584856.jpg: 640x640 (no detections), 10.8ms
# image 68/82 /kaggle/input/construction-site-safety-image-dataset-roboflow/css-data/test/images/youtube-263_jpg.rf.374e343e12ead395440dbd81417e1be9.jpg: 640x640 2 Persons, 1 Safety Vest, 1 machinery, 10 vehicles, 10.8ms
# image 69/82 /kaggle/input/construction-site-safety-image-dataset-roboflow/css-data/test/images/youtube-263_jpg.rf.bb17b89dd2ec9a090ce53b728f48865e.jpg: 640x640 1 Hardhat, 1 NO-Safety Vest, 1 Person, 11.0ms
# image 70/82 /kaggle/input/construction-site-safety-image-dataset-roboflow/css-data/test/images/youtube-34_jpg.rf.03eacc444bae3c5caa3fef5c736c3e40.jpg: 640x640 1 NO-Hardhat, 1 NO-Mask, 1 NO-Safety Vest, 1 Person, 1 machinery, 1 vehicle, 11.2ms
# image 71/82 /kaggle/input/construction-site-safety-image-dataset-roboflow/css-data/test/images/youtube-388_jpg.rf.18caa1da4f818a65f73e48463cb2270e.jpg: 640x640 3 machinerys, 11.6ms
# image 72/82 /kaggle/input/construction-site-safety-image-dataset-roboflow/css-data/test/images/youtube-462_jpg.rf.df73aa5089a04b8fbf3adf9d614a6740.jpg: 640x640 2 Hardhats, 3 Persons, 2 Safety Vests, 3 vehicles, 11.4ms
# image 73/82 /kaggle/input/construction-site-safety-image-dataset-roboflow/css-data/test/images/youtube-471_jpg.rf.4296b7bd9a5a07753077beddbcd651bf.jpg: 640x640 1 Person, 1 Safety Vest, 11.1ms
# image 74/82 /kaggle/input/construction-site-safety-image-dataset-roboflow/css-data/test/images/youtube-472_jpg.rf.e9425ff40c0df2beeef70abbc2324956.jpg: 640x640 1 Person, 1 Safety Vest, 11.1ms
# image 75/82 /kaggle/input/construction-site-safety-image-dataset-roboflow/css-data/test/images/youtube-496_jpg.rf.def4e9964e9a354d0a02f4ac14334a73.jpg: 640x640 (no detections), 11.1ms
# image 76/82 /kaggle/input/construction-site-safety-image-dataset-roboflow/css-data/test/images/youtube-510_jpg.rf.62f82e36d134d53587edb48f291986f4.jpg: 640x640 1 Person, 11.9ms
# image 77/82 /kaggle/input/construction-site-safety-image-dataset-roboflow/css-data/test/images/youtube-53_jpg.rf.e96f8f81389f4e63a79663095680a617.jpg: 640x640 1 Hardhat, 2 NO-Safety Vests, 2 Persons, 1 machinery, 3 vehicles, 11.2ms
# image 78/82 /kaggle/input/construction-site-safety-image-dataset-roboflow/css-data/test/images/youtube-596_jpg.rf.11a8a4ac01d8aadb80eeb0406dfa579a.jpg: 640x640 1 NO-Safety Vest, 1 Person, 11.1ms
# image 79/82 /kaggle/input/construction-site-safety-image-dataset-roboflow/css-data/test/images/youtube-631_jpg.rf.7c6ecf859c1b0a659f8ea057ad27aebd.jpg: 640x640 1 Hardhat, 1 NO-Mask, 3 Persons, 1 Safety Vest, 11.3ms
# image 80/82 /kaggle/input/construction-site-safety-image-dataset-roboflow/css-data/test/images/youtube-671_jpg.rf.7b08643d6754cabe6caf2b49a963de47.jpg: 640x640 (no detections), 12.3ms
# image 81/82 /kaggle/input/construction-site-safety-image-dataset-roboflow/css-data/test/images/youtube-738_jpg.rf.6f300b76e12b325f7c373c95ef319005.jpg: 640x640 1 Hardhat, 1 NO-Mask, 1 Person, 2 Safety Vests, 11.4ms
# image 82/82 /kaggle/input/construction-site-safety-image-dataset-roboflow/css-data/test/images/youtube-840_jpg.rf.974a83a7c5aee7c16e83435b043c6d96.jpg: 640x640 1 Hardhat, 1 NO-Mask, 1 Person, 1 Safety Vest, 2 vehicles, 11.3ms
# Speed: 0.5ms preprocess, 11.7ms inference, 1.5ms postprocess per image at shape (1, 3, 640, 640)
# Results saved to runs/detect/predict2

# %%
# %matplotlib inline

predicitions = glob.glob(os.path.join(WORK_DIR, 'runs/detect/predict2', '*'))

n = 10

for i in range(n):
    idx = np.random.randint(0, len(predicitions))
    image = Image.open(predicitions[idx])
    plt.imshow(image)
    plt.grid(False)
    plt.show()
